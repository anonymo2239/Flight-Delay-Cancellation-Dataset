# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("suryanarayanan02/flight-delay-prediction-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/suryanarayanan02/flight-delay-prediction-dataset/versions/1

# %%
import pandas as pd

flights = pd.read_csv("/root/.cache/kagglehub/datasets/suryanarayanan02/flight-delay-prediction-dataset/versions/1/flights.csv")
df = flights.copy()
df.head()
# Out:
# <ipython-input-2-2a31825929d9>:3: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   flights = pd.read_csv("/root/.cache/kagglehub/datasets/suryanarayanan02/flight-delay-prediction-dataset/versions/1/flights.csv")
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# ...

# %%
df.shape
# Out:
# (5819079, 31)

# %%
year = df.YEAR[0]
year
# Out:
# 2015

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 31 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   YEAR                 int64
#  1   MONTH                int64
#  2   DAY                  int64
#  3   DAY_OF_WEEK          int64
#  4   AIRLINE              object
#  5   FLIGHT_NUMBER        int64
#  6   TAIL_NUMBER          object
#  7   ORIGIN_AIRPORT       object
#  8   DESTINATION_AIRPORT  object
#  9   SCHEDULED_DEPARTURE  int64
#  10  DEPARTURE_TIME       float64
#  11  DEPARTURE_DELAY      float64
#  12  TAXI_OUT             float64
#  13  WHEELS_OFF           float64
#  14  SCHEDULED_TIME       float64
#  15  ELAPSED_TIME         float64
#  16  AIR_TIME             float64
#  17  DISTANCE             int64
#  18  WHEELS_ON            float64
#  19  TAXI_IN              float64
#  20  SCHEDULED_ARRIVAL    int64
#  21  ARRIVAL_TIME         float64
#  22  ARRIVAL_DELAY        float64
# ...

# %%
df.FLIGHT_NUMBER.value_counts()
# Out:
# FLIGHT_NUMBER
# 469     3975
# 327     3554
# 326     3513
# 188     3386
# 403     3370
#         ...
# 6783       1
# 6757       1
# 6752       1
# 6793       1
# 6887       1
# Name: count, Length: 6952, dtype: int64

# %%
df.describe()
# Out:
#             YEAR         MONTH           DAY   DAY_OF_WEEK  FLIGHT_NUMBER  \
# count  5819079.0  5.819079e+06  5.819079e+06  5.819079e+06   5.819079e+06
# mean      2015.0  6.524085e+00  1.570459e+01  3.926941e+00   2.173093e+03
# std          0.0  3.405137e+00  8.783425e+00  1.988845e+00   1.757064e+03
# min       2015.0  1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# 25%       2015.0  4.000000e+00  8.000000e+00  2.000000e+00   7.300000e+02
# 50%       2015.0  7.000000e+00  1.600000e+01  4.000000e+00   1.690000e+03
# 75%       2015.0  9.000000e+00  2.300000e+01  6.000000e+00   3.230000e+03
# max       2015.0  1.200000e+01  3.100000e+01  7.000000e+00   9.855000e+03
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY      TAXI_OUT  \
# count         5.819079e+06    5.732926e+06     5.732926e+06  5.730032e+06
# mean          1.329602e+03    1.335204e+03     9.370158e+00  1.607166e+01
# std           4.837518e+02    4.964233e+02     3.708094e+01  8.895574e+00
# ...

# %%
df.isnull().sum()
# Out:
# YEAR                         0
# MONTH                        0
# DAY                          0
# DAY_OF_WEEK                  0
# AIRLINE                      0
# FLIGHT_NUMBER                0
# TAIL_NUMBER              14721
# ORIGIN_AIRPORT               0
# DESTINATION_AIRPORT          0
# SCHEDULED_DEPARTURE          0
# DEPARTURE_TIME           86153
# DEPARTURE_DELAY          86153
# TAXI_OUT                 89047
# WHEELS_OFF               89047
# SCHEDULED_TIME               6
# ELAPSED_TIME            105071
# AIR_TIME                105071
# DISTANCE                     0
# WHEELS_ON                92513
# TAXI_IN                  92513
# SCHEDULED_ARRIVAL            0
# ARRIVAL_TIME             92513
# ARRIVAL_DELAY           105071
# DIVERTED                     0
# CANCELLED                    0
# CANCELLATION_REASON    5729195
# AIR_SYSTEM_DELAY       4755640
# SECURITY_DELAY         4755640
# AIRLINE_DELAY          4755640
# LATE_AIRCRAFT_DELAY    4755640
# ...

# %%
x = 2695

# %%
df_2695_2700 = df.loc[x:x+5, 'SCHEDULED_DEPARTURE':'ARRIVAL_DELAY'].drop(['DISTANCE'], axis=1)
df_2695_2700
# Out:
#       SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY  TAXI_OUT  \
# 2695                  915           913.0             -2.0      14.0
# 2696                  915           914.0             -1.0      17.0
# 2697                  915             NaN              NaN       NaN
# 2698                  915           956.0             41.0       8.0
# 2699                  915           914.0             -1.0       9.0
# 2700                  915           914.0             -1.0      17.0
#
#       WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  WHEELS_ON  TAXI_IN  \
# 2695       927.0           283.0         274.0     254.0     1141.0      6.0
# 2696       931.0           125.0         128.0     106.0     1117.0      5.0
# 2697         NaN           175.0           NaN       NaN        NaN      NaN
# 2698      1004.0           187.0         166.0     154.0     1138.0      4.0
# 2699       923.0           355.0         343.0     326.0     1149.0      8.0
# ...

# %%
df.loc[(df['CANCELLED'] == 0) & (df['CANCELLATION_REASON'].notna())]
# Out:
# Empty DataFrame
# Columns: [YEAR, MONTH, DAY, DAY_OF_WEEK, AIRLINE, FLIGHT_NUMBER, TAIL_NUMBER, ORIGIN_AIRPORT, DESTINATION_AIRPORT, SCHEDULED_DEPARTURE, DEPARTURE_TIME, DEPARTURE_DELAY, TAXI_OUT, WHEELS_OFF, SCHEDULED_TIME, ELAPSED_TIME, AIR_TIME, DISTANCE, WHEELS_ON, TAXI_IN, SCHEDULED_ARRIVAL, ARRIVAL_TIME, ARRIVAL_DELAY, DIVERTED, CANCELLED, CANCELLATION_REASON, AIR_SYSTEM_DELAY, SECURITY_DELAY, AIRLINE_DELAY, LATE_AIRCRAFT_DELAY, WEATHER_DELAY]
# Index: []
#
# [0 rows x 31 columns]

# %%
df.CANCELLATION_REASON.value_counts()
# Out:
# CANCELLATION_REASON
# B    48851
# A    25262
# C    15749
# D       22
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 31 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   YEAR                 int64
#  1   MONTH                int64
#  2   DAY                  int64
#  3   DAY_OF_WEEK          int64
#  4   AIRLINE              object
#  5   FLIGHT_NUMBER        int64
#  6   TAIL_NUMBER          object
#  7   ORIGIN_AIRPORT       object
#  8   DESTINATION_AIRPORT  object
#  9   SCHEDULED_DEPARTURE  int64
#  10  DEPARTURE_TIME       float64
#  11  DEPARTURE_DELAY      float64
#  12  TAXI_OUT             float64
#  13  WHEELS_OFF           float64
#  14  SCHEDULED_TIME       float64
#  15  ELAPSED_TIME         float64
#  16  AIR_TIME             float64
#  17  DISTANCE             int64
#  18  WHEELS_ON            float64
#  19  TAXI_IN              float64
#  20  SCHEDULED_ARRIVAL    int64
#  21  ARRIVAL_TIME         float64
#  22  ARRIVAL_DELAY        float64
# ...

# %%
df[df.select_dtypes('object').columns] = df.select_dtypes('object').astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 31 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   YEAR                 int64
#  1   MONTH                int64
#  2   DAY                  int64
#  3   DAY_OF_WEEK          int64
#  4   AIRLINE              category
#  5   FLIGHT_NUMBER        int64
#  6   TAIL_NUMBER          category
#  7   ORIGIN_AIRPORT       category
#  8   DESTINATION_AIRPORT  category
#  9   SCHEDULED_DEPARTURE  int64
#  10  DEPARTURE_TIME       float64
#  11  DEPARTURE_DELAY      float64
#  12  TAXI_OUT             float64
#  13  WHEELS_OFF           float64
#  14  SCHEDULED_TIME       float64
#  15  ELAPSED_TIME         float64
#  16  AIR_TIME             float64
#  17  DISTANCE             int64
#  18  WHEELS_ON            float64
#  19  TAXI_IN              float64
#  20  SCHEDULED_ARRIVAL    int64
#  21  ARRIVAL_TIME         float64
# ...

# %%
semi_clean_df = df.drop(['CANCELLATION_REASON', 'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'], axis=1)

# %%
semi_clean_df
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
semi_clean_df = semi_clean_df.drop(semi_clean_df.loc[(semi_clean_df['DIVERTED'] == 1) | (semi_clean_df['CANCELLED'] == 1)].index, axis=0)
semi_clean_df = semi_clean_df.drop(['YEAR', 'DIVERTED', 'CANCELLED'], axis=1)
semi_clean_df
# Out:
#          MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0            1    1            4      AS             98      N407AS
# 1            1    1            4      AA           2336      N3KUAA
# 2            1    1            4      US            840      N171US
# 3            1    1            4      AA            258      N3HYAA
# 4            1    1            4      AS            135      N527AS
# ...        ...  ...          ...     ...            ...         ...
# 5819074     12   31            4      B6            688      N657JB
# 5819075     12   31            4      B6            745      N828JB
# 5819076     12   31            4      B6           1503      N913JB
# 5819077     12   31            4      B6            333      N527JB
# 5819078     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 0                  ANC                 SEA                    5
# ...

# %%
# BURAYA KADAR semi_clean_df, MODELDE "KULLANILMAYACAK ÖZELLIKLERDEN" TEMIZLENMIŞTIR VE OBJECT DEĞİŞKENLER CATEGORY E DÖNÜŞTÜRÜLMÜŞTÜR.
# EKSİK VEYA AYKIRI GÖZLEM TEMİZLİĞİ YAPILMAMIŞTIR.
# YIL DEĞİŞKENİ GRAFİK OLUŞTURMADA LAZIM OLABİLECEĞİ İÇİN year DEĞİŞKENİNE ATANMIŞTIR.

# %%
semi_clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5714008 entries, 0 to 5819078
# Data columns (total 22 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   MONTH                int64
#  1   DAY                  int64
#  2   DAY_OF_WEEK          int64
#  3   AIRLINE              category
#  4   FLIGHT_NUMBER        int64
#  5   TAIL_NUMBER          category
#  6   ORIGIN_AIRPORT       category
#  7   DESTINATION_AIRPORT  category
#  8   SCHEDULED_DEPARTURE  int64
#  9   DEPARTURE_TIME       float64
#  10  DEPARTURE_DELAY      float64
#  11  TAXI_OUT             float64
#  12  WHEELS_OFF           float64
#  13  SCHEDULED_TIME       float64
#  14  ELAPSED_TIME         float64
#  15  AIR_TIME             float64
#  16  DISTANCE             int64
#  17  WHEELS_ON            float64
#  18  TAXI_IN              float64
#  19  SCHEDULED_ARRIVAL    int64
#  20  ARRIVAL_TIME         float64
#  21  ARRIVAL_DELAY        float64
# ...
